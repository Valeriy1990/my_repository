# %%
data = ''

l=[]
data = data.split()
repr(data)
# Out:
# '[]'

# %%
import csv

with open('Погода_2024.csv', 'r', encoding='utf-8') as file:
    rows = csv.reader(file)
    for row in rows:
        print(row)
# Out:
# ['Date;t;h']
# ['01.02.2024;1;-2']
# ['02.02.2024;1;-4']
# ['03.02.2024;-4;-8']
# ['04.02.2024;-5;-8']
# ['05.02.2024;-3;-8']
# ['06.02.2024;-8;-15']
# ['07.02.2024;-14;-24']
# ['08.02.2024;-15;-20']
# ['09.02.2024;-13;-20']
# ['10.02.2024;-13;-28']
# ['11.02.2024;-10;-26']
# ['12.02.2024;-6;-10']
# ['13.02.2024;-7;-16']
# ['14.02.2024;-14;-25']
# ['15.02.2024;-13;-19']
# ['16.02.2024;-10;-14']
# ['17.02.2024;-4;-11']
# ['18.02.2024;-1;-5']
# ['19.02.2024;-3;-8']
# ['20.02.2024;-4;-10']
# ['21.02.2024;-4;-11']
# ['22.02.2024;-4;-8']
# ['23.02.2024;-2;-5']
# ['24.02.2024;0;-2']
# ['25.02.2024;0;-3']
# ['26.02.2024;-1;-5']
# ['27.02.2024;0;-6']
# ['28.02.2024;0;-7']
# ['29.02.2024;1;-2']
# ['01.03.2024;1;-1']
# ['02.03.2024;0;-3']
# ['03.03.2024;0;-10']
# ['04.03.2024;0;-13']
# ['05.03.2024;-2;-17']
# ['06.03.2024;-3;-21']
# ['07.03.2024;-2;-8']
# ['08.03.2024;0;-8']
# ['09.03.2024;-5;-15']
# ['10.03.2024;-4;-17']
# ['11.03.2024;-1;-15']
# ['12.03.2024;0;-4']
# ['13.03.2024;0;-7']
# ...
